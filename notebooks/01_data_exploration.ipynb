# %% [markdown]
# # 01. Data Exploration
#
# Initial profiling and structure analysis of Aadhaar datasets.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
from src.data_loader import load_all_datasets

# %%
enrolment, demographic, biometric = load_all_datasets()

print(f"Enrolment: {len(enrolment):,} records")
print(f"Demographic: {len(demographic):,} records")
print(f"Biometric: {len(biometric):,} records")

# %% [markdown]
# ## Enrolment Dataset Structure

# %%
enrolment.info()
enrolment.head(10)

# %%
enrolment.describe()

# %%
print(f"Unique states: {enrolment['state'].nunique()}")
print(f"Unique districts: {enrolment['district'].nunique()}")
print(f"Date range: {enrolment['date'].min()} to {enrolment['date'].max()}")

# %% [markdown]
# ## Demographic Update Dataset Structure

# %%
demographic.info()
demographic.head(10)

# %%
demographic.describe()

# %% [markdown]
# ## Biometric Update Dataset Structure

# %%
biometric.info()
biometric.head(10)

# %%
biometric.describe()

# %% [markdown]
# ## Missing Values Analysis

# %%
print("Enrolment missing values:")
print(enrolment.isnull().sum())

print("\nDemographic missing values:")
print(demographic.isnull().sum())

print("\nBiometric missing values:")
print(biometric.isnull().sum())

# %% [markdown]
# ## Duplicate Records

# %%
print(f"Enrolment duplicates: {enrolment.duplicated().sum():,}")
print(f"Demographic duplicates: {demographic.duplicated().sum():,}")
print(f"Biometric duplicates: {biometric.duplicated().sum():,}")

# %% [markdown]
# ## State Distribution

# %%
enrolment['state'].value_counts().head(20)
